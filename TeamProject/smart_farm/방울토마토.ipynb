# %% [markdown]
# <a href="https://colab.research.google.com/github/sexymonster/Projects/blob/main/TeamProject/%EB%B0%A9%EC%9A%B8%ED%86%A0%EB%A7%88%ED%86%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
env_df = pd.read_csv("./envdata.csv")
live_df = pd.read_csv("./livedata.csv")

# %%
env_df
# Out:
#             수집일  내부CO2(ppm)  이슬점온도(도)  (양액)공급EC(dS/m)  토양EC(dS/m)  \
# 0    2021-07-29      337.94     28.13             NaN        0.60
# 1    2021-07-30      322.87     29.25             NaN        0.50
# 2    2021-07-31      314.07     29.86             NaN        0.65
# 3    2021-08-01      323.67     27.65             NaN        0.69
# 4    2021-08-02      335.71     23.58             NaN        0.72
# ..          ...         ...       ...             ...         ...
# 192  2022-03-14      405.91     13.78             NaN         NaN
# 193  2022-03-15      388.13     13.04             NaN         NaN
# 194  2022-03-16      391.96     12.78             NaN         NaN
# 195  2022-03-17      409.65     13.22             NaN         NaN
# 196  2022-03-18      326.88     12.42             NaN         NaN
#
#      (양액)배액EC(dS/m)  외부습도(%)  내부습도(%)  지습(%)  (양액)공급PH(ph)  ...  (양액)배액PH  \
# 0               NaN      NaN    65.71  50.82           NaN  ...       NaN
# ...

# %%
env_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   수집일             197 non-null    object
#  1   내부CO2(ppm)      167 non-null    float64
#  2   이슬점온도(도)        171 non-null    float64
#  3   (양액)공급EC(dS/m)  0 non-null      float64
#  4   토양EC(dS/m)      158 non-null    float64
#  5   (양액)배액EC(dS/m)  0 non-null      float64
#  6   외부습도(%)         0 non-null      float64
#  7   내부습도(%)         170 non-null    float64
#  8   지습(%)           170 non-null    float64
#  9   (양액)공급PH(ph)    0 non-null      float64
#  10  토양PH(ph)        158 non-null    float64
#  11  (양액)배액PH        0 non-null      float64
#  12  강우감지            158 non-null    float64
#  13  (양액)총급액(ℓ)      0 non-null      float64
#  14  (양액)총배액(ℓ)      0 non-null      float64
#  15  일사량(W/m-2·s)    166 non-null    float64
#  16  외부온도(도)         167 non-null    float64
# ...

# %%
env_df = env_df.drop(env_df.columns[[3,5,6,9,11,13,14,19]], axis=1)

# %%
env_df.head()
# Out:
#           수집일  내부CO2(ppm)  이슬점온도(도)  토양EC(dS/m)  내부습도(%)  지습(%)  토양PH(ph)  \
# 0  2021-07-29      337.94     28.13        0.60    65.71  50.82       0.0
# 1  2021-07-30      322.87     29.25        0.50    65.84  52.27       0.0
# 2  2021-07-31      314.07     29.86        0.65    65.91  51.30       0.0
# 3  2021-08-01      323.67     27.65        0.69    65.54  47.25       0.0
# 4  2021-08-02      335.71     23.58        0.72    57.67  45.94       0.0
#
#    강우감지  일사량(W/m-2·s)  외부온도(도)  내부온도(도)  지온(도)  외부풍속(m/s)
# 0  0.00        227.76    27.04    18.97  27.68       0.20
# 1  0.00        226.20    27.56    19.10  28.46       0.57
# 2  0.02        295.50    27.88    19.91  30.33       0.36
# 3  0.07        270.26    27.29    19.44  27.62       0.21
# 4  0.16        144.68    24.68    17.64  27.70       0.30

# %%
env_df.iloc[:,6].unique()
# Out:
# array([ 0., nan])

# %%
env_df = env_df.drop(env_df.columns[6], axis=1)

# %%
env_df.head()
# Out:
#           수집일  내부CO2(ppm)  이슬점온도(도)  토양EC(dS/m)  내부습도(%)  지습(%)  강우감지  \
# 0  2021-07-29      337.94     28.13        0.60    65.71  50.82  0.00
# 1  2021-07-30      322.87     29.25        0.50    65.84  52.27  0.00
# 2  2021-07-31      314.07     29.86        0.65    65.91  51.30  0.02
# 3  2021-08-01      323.67     27.65        0.69    65.54  47.25  0.07
# 4  2021-08-02      335.71     23.58        0.72    57.67  45.94  0.16
#
#    일사량(W/m-2·s)  외부온도(도)  내부온도(도)  지온(도)  외부풍속(m/s)
# 0        227.76    27.04    18.97  27.68       0.20
# 1        226.20    27.56    19.10  28.46       0.57
# 2        295.50    27.88    19.91  30.33       0.36
# 3        270.26    27.29    19.44  27.62       0.21
# 4        144.68    24.68    17.64  27.70       0.30

# %%
env_sdf = env_df.iloc[115:,:]

# %%
env_sdf
# Out:
#             수집일  내부CO2(ppm)  이슬점온도(도)  토양EC(dS/m)  내부습도(%)  지습(%)  강우감지  \
# 115  2021-11-21      416.13     13.57         1.0    61.20  69.32  0.00
# 116  2021-11-22      373.88     11.75         1.0    61.33  69.06  0.36
# 117  2021-11-23      353.94     10.81         1.0    60.67  68.97  0.21
# 118  2021-11-24      339.07     11.90         1.0    60.09  68.86  0.13
# 119  2021-11-25      363.87     11.81         1.0    58.33  69.05  0.02
# ..          ...         ...       ...         ...      ...    ...   ...
# 192  2022-03-14      405.91     13.78         NaN    62.51  80.00   NaN
# 193  2022-03-15      388.13     13.04         NaN    53.17  80.83   NaN
# 194  2022-03-16      391.96     12.78         NaN    56.15  81.35   NaN
# 195  2022-03-17      409.65     13.22         NaN    64.01  81.00   NaN
# 196  2022-03-18      326.88     12.42         NaN    63.53  81.00   NaN
#
#      일사량(W/m-2·s)  외부온도(도)  내부온도(도)  지온(도)  외부풍속(m/s)
# ...

# %%
env_df.수집일.unique()
# Out:
# array(['2021-07-29', '2021-07-30', '2021-07-31', '2021-08-01',
#        '2021-08-02', '2021-08-03', '2021-08-04', '2021-08-05',
#        '2021-08-06', '2021-08-07', '2021-08-08', '2021-08-09',
#        '2021-08-10', '2021-08-11', '2021-08-12', '2021-08-13',
#        '2021-08-14', '2021-08-15', '2021-08-16', '2021-08-17',
#        '2021-08-18', '2021-08-19', '2021-08-20', '2021-08-21',
#        '2021-08-22', '2021-08-23', '2021-08-24', '2021-08-25',
#        '2021-08-26', '2021-08-27', '2021-08-28', '2021-08-29',
#        '2021-08-30', '2021-08-31', '2021-09-01', '2021-09-02',
#        '2021-09-03', '2021-09-04', '2021-09-05', '2021-09-06',
#        '2021-09-07', '2021-09-08', '2021-09-09', '2021-09-10',
#        '2021-09-11', '2021-09-12', '2021-09-13', '2021-09-14',
#        '2021-09-15', '2021-09-16', '2021-09-17', '2021-09-18',
#        '2021-09-19', '2021-09-20', '2021-09-21', '2021-09-22',
#        '2021-09-23', '2021-09-24', '2021-09-25', '2021-09-26',
# ...

# %%
live_df.head()
# Out:
#           조사일  주차  생장길이(cm)  화방높이(cm)  줄기굵기(mm)  엽장(cm)  엽폭(cm)  엽수(개)  \
# 0  2021-11-27  18       0.0    239.50      9.20  482.25  442.25  10.50
# 1  2021-12-04  19     202.5    227.50      9.97  476.75  366.50  11.00
# 2  2021-12-11  20     252.5    138.75      7.39  454.25  344.75  10.00
# 3  2021-12-18  21     172.5    290.00      9.88  449.75  394.50  11.00
# 4  2021-12-25  22     187.5    232.50      9.41  419.00  359.75  12.75
#
#    개화군(점)  착과군(점)  열매수(개)  최종화방번호(번)
# 0   13.84   12.93   86.00      14.50
# 1   14.45   13.38   93.75      15.00
# 2   15.26   14.37   77.00      16.00
# 3   15.49   14.66   85.25      16.00
# 4   16.05   15.69   91.50      16.75

# %%
live_df.조사일.unique()
# Out:
# array(['2021-11-27', '2021-12-04', '2021-12-11', '2021-12-18',
#        '2021-12-25', '2022-01-01', '2022-01-06', '2022-01-15',
#        '2022-01-22', '2022-01-29', '2022-02-05', '2022-02-12',
#        '2022-02-19', '2022-02-26', '2022-03-05', '2022-03-12'],
#       dtype=object)

# %%
fea_df = live_df.iloc[:,1:11]

# %%
fea_df.corr()
# Out:
#                 주차  생장길이(cm)  화방높이(cm)  줄기굵기(mm)    엽장(cm)    엽폭(cm)  \
# 주차        1.000000  0.425655 -0.004628 -0.273849 -0.710478 -0.579176
# 생장길이(cm)  0.425655  1.000000 -0.124328 -0.139763 -0.317194 -0.563069
# 화방높이(cm) -0.004628 -0.124328  1.000000  0.661046 -0.022034  0.302550
# 줄기굵기(mm) -0.273849 -0.139763  0.661046  1.000000  0.352803  0.719122
# 엽장(cm)   -0.710478 -0.317194 -0.022034  0.352803  1.000000  0.582785
# 엽폭(cm)   -0.579176 -0.563069  0.302550  0.719122  0.582785  1.000000
# 엽수(개)    -0.496330 -0.158256 -0.206440  0.127780  0.363246  0.170206
# 개화군(점)    0.997843  0.431645 -0.042332 -0.318883 -0.708161 -0.606419
# 착과군(점)    0.997268  0.433934  0.010847 -0.281075 -0.719437 -0.580551
# 열매수(개)    0.321252  0.076691  0.069060 -0.089040 -0.197998 -0.354614
#
#              엽수(개)    개화군(점)    착과군(점)    열매수(개)
# 주차       -0.496330  0.997843  0.997268  0.321252
# 생장길이(cm) -0.158256  0.431645  0.433934  0.076691
# 화방높이(cm) -0.206440 -0.042332  0.010847  0.069060
# ...

# %% [markdown]
# 열매수와 그나마 관련이 있는 피쳐값에는 주차, 엽폭, 개화군, 착화군이 있지만\
# 잘 성장한 작물의 기준이 열매 수 인지는 고려를 해봐야 할 거 같다

# %%
sns.heatmap(fea_df.corr(), linewidths = 0.1, vmax = 0.5, linecolor="white",annot=True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44600 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
